# %%
from roboflow import Roboflow
# rf = Roboflow(api_key="SbmR4zyin4CLhA0nsUJR")
project = rf.workspace("justgettingstarted").project("football-x74yb")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-1 in yolov8:: 100%|██████████| 85/85 [00:00<00:00, 1140.57it/s]
