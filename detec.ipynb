# %%
from ultralytics import YOLO as y
import cv2 as cv

# %%
model = y('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:12<00:00, 504kB/s]

# %%
results = model('image.png', save=True)
# Out:
# image 1/1 d:\Smoke_IT\YoLoCV\image.png: 416x640 2 persons, 94.4ms
# Speed: 4.2ms preprocess, 94.4ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
