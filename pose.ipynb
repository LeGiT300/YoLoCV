# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-pose.pt')
source = 'https://ultralytics.com/images/bus.jpg'
model.predict(source=source, save=True, imgsz=320, conf=0.5)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 d:\Smoke_IT\YoLo\bus.jpg: 320x256 2 persons, 72.7ms
# Speed: 2.3ms preprocess, 72.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs\pose\predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[119, 146, 172],
#          [121, 148, 174],
#          [122, 152, 177],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[120, 147, 173],
#          [122, 149, 175],
#          [123, 153, 178],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[123, 150, 176],
#          [124, 151, 177],
#          [125, 155, 180],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         ...,
#
#         [[183, 182, 186],
#          [179, 178, 182],
#          [180, 179, 183],
#          ...,
#          [121, 111, 117],
#          [113, 103, 109],
#          [115, 105, 111]],
#
#         [[165, 164, 168],
#          [173, 172, 176],
#          [187, 186, 190],
#          ...,
#          [102,  92,  98],
#          [101,  91,  97],
#          [103,  93,  99]],
#
#         [[123, 122, 126],
#          [145, 144, 148],
#          [176, 175, 179],
#          ...,
#          [ 95,  85,  91],
#          [ 96,  86,  92],
#          [ 98,  88,  94]]], dtype=uint8)
#  orig_shape: (1080, 810)
#  path: 'd:\\Smoke_IT\\YoLo\\bus.jpg'
#  probs: None
#  save_dir: 'runs\\pose\\predict3'
#  speed: {'preprocess': 2.2621999960392714, 'inference': 72.72140000713989, 'postprocess': 1.5251000004354864}]

# %%
import cv2 as cv

cap = cv.VideoCapture(0)
model = YOLO('yolov8n-pose.pt')


if not cap.isOpened():
    print('Could not get frame')
    exit()


while True:
    ret, frame = cap.read()

    if ret:
        results = model(frame, save=True)
        annotated = results[0].plot()

        cv.imshow('pose', annotated)

        if cv.waitKey(1) == ord('q'):
            break
    else:
        print('Could not get frames')
        break


cap.release()
cv.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 134.6ms
# Speed: 8.6ms preprocess, 134.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 136.6ms
# Speed: 6.0ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 132.1ms
# Speed: 6.6ms preprocess, 132.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 96.4ms
# Speed: 1.3ms preprocess, 96.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 94.2ms
# Speed: 1.4ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 87.5ms
# Speed: 1.3ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.5ms
# Speed: 1.5ms preprocess, 83.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 95.1ms
# Speed: 1.5ms preprocess, 95.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 92.2ms
# Speed: 1.6ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 86.3ms
# Speed: 1.6ms preprocess, 86.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 92.4ms
# Speed: 1.3ms preprocess, 92.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 86.5ms
# Speed: 1.4ms preprocess, 86.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 101.6ms
# Speed: 1.4ms preprocess, 101.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 89.9ms
# Speed: 1.7ms preprocess, 89.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.9ms
# Speed: 1.3ms preprocess, 83.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.3ms
# Speed: 1.5ms preprocess, 83.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 81.3ms
# Speed: 1.5ms preprocess, 81.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.3ms
# Speed: 1.4ms preprocess, 83.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 87.2ms
# Speed: 2.2ms preprocess, 87.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 1.3ms preprocess, 79.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 1.4ms preprocess, 85.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 81.0ms
# Speed: 1.6ms preprocess, 81.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 79.9ms
# Speed: 1.6ms preprocess, 79.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 79.9ms
# Speed: 1.4ms preprocess, 79.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 1.5ms preprocess, 89.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 100.3ms
# Speed: 1.5ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 102.8ms
# Speed: 1.5ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 95.8ms
# Speed: 1.3ms preprocess, 95.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 90.4ms
# Speed: 1.6ms preprocess, 90.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 97.5ms
# Speed: 1.7ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 145.8ms
# Speed: 1.4ms preprocess, 145.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 95.8ms
# Speed: 1.5ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 86.4ms
# Speed: 1.3ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 85.1ms
# Speed: 1.3ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 100.8ms
# Speed: 1.4ms preprocess, 100.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 95.5ms
# Speed: 1.5ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 94.9ms
# Speed: 1.4ms preprocess, 94.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 101.4ms
# Speed: 1.8ms preprocess, 101.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 93.7ms
# Speed: 1.6ms preprocess, 93.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 91.8ms
# Speed: 1.5ms preprocess, 91.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 97.6ms
# Speed: 2.5ms preprocess, 97.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 86.6ms
# Speed: 1.3ms preprocess, 86.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 91.7ms
# Speed: 1.3ms preprocess, 91.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 80.5ms
# Speed: 1.7ms preprocess, 80.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 84.4ms
# Speed: 1.4ms preprocess, 84.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.5ms
# Speed: 1.4ms preprocess, 83.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 100.3ms
# Speed: 1.3ms preprocess, 100.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 108.8ms
# Speed: 1.5ms preprocess, 108.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 92.1ms
# Speed: 1.4ms preprocess, 92.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 91.3ms
# Speed: 1.7ms preprocess, 91.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 87.7ms
# Speed: 1.4ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.4ms
# Speed: 1.7ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 90.0ms
# Speed: 1.9ms preprocess, 90.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 99.3ms
# Speed: 2.3ms preprocess, 99.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 92.3ms
# Speed: 2.3ms preprocess, 92.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 82.0ms
# Speed: 1.3ms preprocess, 82.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 83.0ms
# Speed: 1.4ms preprocess, 83.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 86.0ms
# Speed: 1.9ms preprocess, 86.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 98.9ms
# Speed: 1.4ms preprocess, 98.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 82.4ms
# Speed: 2.4ms preprocess, 82.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
#
# 0: 480x640 (no detections), 87.8ms
# Speed: 1.4ms preprocess, 87.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict4
